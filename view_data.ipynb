# %% [markdown]
# Display a subset of the dataset

# %%
from Data.data import TripletDataset
from Util.graph import show_triplet_img
from torchvision import transforms

LFW_FOLDER_PATH = r'Data\lfw_224'
dataset = TripletDataset(LFW_FOLDER_PATH, transform=transforms.ToTensor())
print(f'Number of triplets: {len(dataset)}')
show_triplet_img(dataset[:5])
# Out:
# Number of triplets: 4307
